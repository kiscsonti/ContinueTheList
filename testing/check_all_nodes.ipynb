# %%
import pickle

# %%
with open("/home/kardosp/continuethelist/stats/extra_data/dbpedia_entities.pickle", "rb") as f:
    all_nodes = pickle.load(f)

with open("/home/kardosp/continuethelist/stats/extra_data/dbpedia_entities2.pickle", "rb") as f:
    all_nodes2 = pickle.load(f)

# %%
print(len(all_nodes))
print(len(all_nodes2))
# Out:
# 1009666
# 6009666

# %%
all_nodes
# Out:
# ['http://dbpedia.org/resource/2015-16_Greek_Handball_Premier',
#  'http://dbpedia.org/resource/2016_Kerala_Premier_League',
#  'http://dbpedia.org/resource/Age_Of_Millennia',
#  'http://dbpedia.org/resource/Anthony_Meggs',
#  'http://dbpedia.org/resource/Attoor_(Kerala)',
#  'http://dbpedia.org/resource/BHARATplaza',
#  'http://dbpedia.org/resource/Baldy_McDonagh',
#  'http://dbpedia.org/resource/Balletcollective',
#  'http://dbpedia.org/resource/Ben_McClain',
#  'http://dbpedia.org/resource/Brenna_murphy',
#  'http://dbpedia.org/resource/Bring_Chrome_Home',
#  'http://dbpedia.org/resource/Capstan_Incorporated',
#  'http://dbpedia.org/resource/Category:1300s_disestablishments_in_Asia',
#  'http://dbpedia.org/resource/Category:1300s_disestablishments_in_India',
#  'http://dbpedia.org/resource/Category:1305_disestablishments',
#  'http://dbpedia.org/resource/Category:1305_disestablishments_by_continent',
#  'http://dbpedia.org/resource/Category:1305_disestablishments_by_country',
# ...

# %%
len(set(all_nodes))
# Out:
# 1009666

# %% [markdown]
# # How many category?

# %%
category = list(filter(lambda x: "Category:" in x, all_nodes2))
print(len(category))
# Out:
# 402488
