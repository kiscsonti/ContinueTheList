# %%
import pandas as pd
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from evaluation.evaluate_script import graph_eval_readable_ranking_main, graph_eval_readable_ranking_comparable_main

# %%
import pickle
from evaluation.evaluate_script import graph_eval_ranking_first
import os
import json

file = "/home/kardosp/continuethelist/outputs/graphwalk_v2_output_sample4.pickle"

with open(file, "rb") as f:
    algo_results = pickle.load(f)

# %%
res_matrix = graph_eval_readable_ranking_main(algo_results, "/home/kardosp/continuethelist/stats/visualized_outputs/graphwalk_v2_ranking.xlsx")

# %%
graph_eval_readable_ranking_comparable_main(algo_results, "/home/kardosp/continuethelist/stats/visualized_outputs/graphwalk_v2_comparable")
# Out:
#  63%|█████████████████████████▉               | 158/250 [06:07<03:45,  2.45s/it]

# %%
res_matrix_compare
# Out:
# [[[['?x',
#     '<http://dbpedia.org/property/operator>',
#     '<http://dbpedia.org/resource/Starwood_Hotels_and_Resorts_Worldwide>'],
#    ['?x', '<http://dbpedia.org/property/address>', '?uri']],
#   '181',
#   'http://dbpedia.org/resource/California',
#   'http://dbpedia.org/resource/San_Francisco',
#   '2',
#   'Calle San Fernando, 2',
#   '1',
#   'http://dbpedia.org/resource/Chennai',
#   'http://dbpedia.org/resource/Tamil_Nadu',
#   'Krakowskie Przedmiescie 42/44',
#   '1900',
#   'http://dbpedia.org/resource/Seattle',
#   '811',
#   '333',
#   '210',
#   'http://dbpedia.org/resource/Atlanta',
#   '10600',
#   'http://dbpedia.org/resource/Westminster,_Colorado',
#   'Main Gulshan Avenue, Plot-01, Road 45, Gulshan-2, Dhaka 1212, Bangladesh',
#   '211',
#   'http://dbpedia.org/resource/San_Jose,_California'],
#  [[['?x',
#     '<http://dbpedia.org/property/operator>',
#     '<http://dbpedia.org/resource/Starwood_Hotels_and_Resorts_Worldwide>'],
# ...

# %%
import numpy as np
import pandas as pd
max_column_length = len(max(res_matrix_compare,key = lambda x: len(x)))

# %%
for i in range(len(res_matrix_compare)):
    while len(res_matrix_compare[i]) != max_column_length:
        res_matrix_compare[i].append("")

# %%
pdf = pd.DataFrame(res_matrix_compare).transpose()
pdf.columns =  ["gold_nodes"] + [f"pred_{i}" for i in range(5)] + ["match_nodes"]

# %%
pdf
# Out:
#                                            gold_nodes
# 0   [[?x, <http://dbpedia.org/property/operator>, ...  \
# 1                                                 181
# 2              http://dbpedia.org/resource/California
# 3           http://dbpedia.org/resource/San_Francisco
# 4                                                   2
# 5                               Calle San Fernando, 2
# 6                                                   1
# 7                 http://dbpedia.org/resource/Chennai
# 8              http://dbpedia.org/resource/Tamil_Nadu
# 9                       Krakowskie Przedmiescie 42/44
# 10                                               1900
# 11                http://dbpedia.org/resource/Seattle
# 12                                                811
# 13                                                333
# 14                                                210
# 15                http://dbpedia.org/resource/Atlanta
# ...

# %%
gold_nodes = pdf["gold_nodes"].tolist()[1:]
pdf.style.apply(lambda x: ["background: green" if v in gold_nodes else "" for v in x], axis = 1)
# Out:
# <style type="text/css">
# ...

# %%
import pandas as pd

# %%
pd.DataFrame(res_matrix)
# Out:
#                                                   0
# 0  [[[?x, <http://dbpedia.org/property/operator>,...  \
# 1  [[[?x, <http://dbpedia.org/property/publisher>...
# 2  [[[<http://dbpedia.org/resource/Arkansas>, <ht...
# 3  [[[?x, <http://dbpedia.org/property/currentMem...
# 4  [[[?x, <http://dbpedia.org/property/magazine>,...
# 5  [[[?uri, <http://dbpedia.org/ontology/order>, ...
# 6  [[[?uri, <http://dbpedia.org/ontology/formerTe...
# 7  [[[?x, <http://dbpedia.org/property/headquarte...
# 8  [[[?uri, <http://dbpedia.org/ontology/origin>,...
# 9  [[[?uri, <http://dbpedia.org/property/distribu...
#
#                                                   1
# 0  [[[?dy, http://dbpedia.org/property/address, ?...  \
# 1  [[[?al, http://dbpedia.org/ontology/nonFiction...
# 2
# 3
# 4  [[[?as, http://dbpedia.org/ontology/author, ?u...
# 5
# 6
# 7
# 8
# 9
#
#                                                   2  3  4  5  6  7  8  9  10
# ...

# %%
pdf = pd.DataFrame(res_matrix)

pdf.columns = ["gold"] + [f"pred_{i}" for i in range(10)] + ["match"]

# %%
pdf
# Out:
#                                                 gold
# 0  [[[?x, <http://dbpedia.org/property/operator>,...  \
# 1  [[[?x, <http://dbpedia.org/property/publisher>...
# 2  [[[<http://dbpedia.org/resource/Arkansas>, <ht...
# 3  [[[?x, <http://dbpedia.org/property/currentMem...
# 4  [[[?x, <http://dbpedia.org/property/magazine>,...
# 5  [[[?uri, <http://dbpedia.org/ontology/order>, ...
# 6  [[[?uri, <http://dbpedia.org/ontology/formerTe...
# 7  [[[?x, <http://dbpedia.org/property/headquarte...
# 8  [[[?uri, <http://dbpedia.org/ontology/origin>,...
# 9  [[[?uri, <http://dbpedia.org/property/distribu...
#
#                                               pred_0
# 0  [[[?dy, http://dbpedia.org/property/address, ?...  \
# 1  [[[?al, http://dbpedia.org/ontology/nonFiction...
# 2
# 3
# 4  [[[?as, http://dbpedia.org/ontology/author, ?u...
# 5
# 6
# 7
# 8
# 9
#
#                                               pred_1 pred_2 pred_3 pred_4
# ...

# %%
x = pdf["gold"].tolist()[0]

# %%
for item in x[0]:
    print(item)
# Out:
# ['?x', '<http://dbpedia.org/property/operator>', '<http://dbpedia.org/resource/Starwood_Hotels_and_Resorts_Worldwide>']
# ['?x', '<http://dbpedia.org/property/address>', '?uri']

# %%
x[0][0]
# Out:
# ['?x',
#  '<http://dbpedia.org/property/operator>',
#  '<http://dbpedia.org/resource/Starwood_Hotels_and_Resorts_Worldwide>']

# %%
len(res_matrix[0][0])
# Out:
# 2

# %%
res_matrix[2]
# Out:
# [[[['resource/Arkansas', 'ontology/language', '?x'],
#    ['?x', 'property/region', '?uri'],
#    ['?x',
#     '<http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#     'ontology/EthnicGroup']],
#   11],
#  [[['?ar', 'http://dbpedia.org/property/region', '?uri'],
#    ['?ar',
#     'http://purl.org/dc/terms/subject',
#     'http://dbpedia.org/resource/Category:English-American_history']]]]

# %%
res_matrix[0]
# Out:
# [[[['?x',
#     'property/operator',
#     'resource/Starwood_Hotels_and_Resorts_Worldwide'],
#    ['?x', 'property/address', '?uri']],
#   20],
#  [[['?dy', 'http://dbpedia.org/property/address', '?uri'],
#    ['?dy',
#     'http://dbpedia.org/ontology/tenant',
#     'http://dbpedia.org/resource/Starwood_Hotels_and_Resorts_Worldwide']],
#   22],
#  [[['?dr', 'http://dbpedia.org/property/address', '?uri'],
#    ['?dr',
#     'http://dbpedia.org/property/operator',
#     'http://dbpedia.org/resource/Starwood_Hotels_and_Resorts_Worldwide']]]]
